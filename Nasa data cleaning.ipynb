# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
df = pd.read_json('https://data.nasa.gov/resource/y77d-th95.json')

# %%
df.head(2)
# Out:
#      name  id nametype recclass   mass  fall                     year  \
# 0  Aachen   1    Valid       L5   21.0  Fell  1880-01-01T00:00:00.000
# 1  Aarhus   2    Valid       H6  720.0  Fell  1951-01-01T00:00:00.000
#
#      reclat   reclong                                        geolocation  \
# 0  50.77500   6.08333  {'type': 'Point', 'coordinates': [6.08333, 50....
# 1  56.18333  10.23333  {'type': 'Point', 'coordinates': [10.23333, 56...
#
#    :@computed_region_cbhk_fwbd  :@computed_region_nnqa_25f4
# 0                          NaN                          NaN
# 1                          NaN                          NaN

# %%
df.isnull().sum()
# Out:
# name                             0
# id                               0
# nametype                         0
# recclass                         0
# mass                            28
# fall                             0
# year                             1
# reclat                          12
# reclong                         12
# geolocation                     12
# :@computed_region_cbhk_fwbd    867
# :@computed_region_nnqa_25f4    866
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         1000 non-null   object
#  1   id                           1000 non-null   int64
#  2   nametype                     1000 non-null   object
#  3   recclass                     1000 non-null   object
#  4   mass                         972 non-null    float64
#  5   fall                         1000 non-null   object
#  6   year                         999 non-null    object
#  7   reclat                       988 non-null    float64
#  8   reclong                      988 non-null    float64
#  9   geolocation                  988 non-null    object
#  10  :@computed_region_cbhk_fwbd  133 non-null    float64
#  11  :@computed_region_nnqa_25f4  134 non-null    float64
# dtypes: float64(5), int64(1), object(6)
# memory usage: 93.9+ KB

# %%
df.shape
# Out:
# (1000, 12)

# %%
df.head(2)
# Out:
#      name  id nametype recclass   mass  fall                     year  \
# 0  Aachen   1    Valid       L5   21.0  Fell  1880-01-01T00:00:00.000
# 1  Aarhus   2    Valid       H6  720.0  Fell  1951-01-01T00:00:00.000
#
#      reclat   reclong                                        geolocation  \
# 0  50.77500   6.08333  {'type': 'Point', 'coordinates': [6.08333, 50....
# 1  56.18333  10.23333  {'type': 'Point', 'coordinates': [10.23333, 56...
#
#    :@computed_region_cbhk_fwbd  :@computed_region_nnqa_25f4
# 0                          NaN                          NaN
# 1                          NaN                          NaN

# %%
df=df.drop([':@computed_region_cbhk_fwbd'],axis=1)
df=df.drop([':@computed_region_nnqa_25f4'],axis=1)

# %%
df.head()
# Out:
#        name   id nametype     recclass      mass  fall  \
# 0    Aachen    1    Valid           L5      21.0  Fell
# 1    Aarhus    2    Valid           H6     720.0  Fell
# 2      Abee    6    Valid          EH4  107000.0  Fell
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  Fell
# 4   Achiras  370    Valid           L6     780.0  Fell
#
#                       year    reclat    reclong  \
# 0  1880-01-01T00:00:00.000  50.77500    6.08333
# 1  1951-01-01T00:00:00.000  56.18333   10.23333
# 2  1952-01-01T00:00:00.000  54.21667 -113.00000
# 3  1976-01-01T00:00:00.000  16.88333  -99.90000
# 4  1902-01-01T00:00:00.000 -33.16667  -64.95000
#
#                                          geolocation
# 0  {'type': 'Point', 'coordinates': [6.08333, 50....
# 1  {'type': 'Point', 'coordinates': [10.23333, 56...
# 2  {'type': 'Point', 'coordinates': [-113, 54.216...
# 3  {'type': 'Point', 'coordinates': [-99.9, 16.88...
# 4  {'type': 'Point', 'coordinates': [-64.95, -33....

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         1000 non-null   object
#  1   id           1000 non-null   int64
#  2   nametype     1000 non-null   object
#  3   recclass     1000 non-null   object
#  4   mass         972 non-null    float64
#  5   fall         1000 non-null   object
#  6   year         999 non-null    object
#  7   reclat       988 non-null    float64
#  8   reclong      988 non-null    float64
#  9   geolocation  988 non-null    object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 78.3+ KB

# %%
df.isnull().sum()
# Out:
# name            0
# id              0
# nametype        0
# recclass        0
# mass           28
# fall            0
# year            1
# reclat         12
# reclong        12
# geolocation    12
# dtype: int64

# %%
df['mass'].replace([np.nan], df['mass'].mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# name            0
# id              0
# nametype        0
# recclass        0
# mass            0
# fall            0
# year            1
# reclat         12
# reclong        12
# geolocation    12
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         1000 non-null   object
#  1   id           1000 non-null   int64
#  2   nametype     1000 non-null   object
#  3   recclass     1000 non-null   object
#  4   mass         1000 non-null   float64
#  5   fall         1000 non-null   object
#  6   year         999 non-null    object
#  7   reclat       988 non-null    float64
#  8   reclong      988 non-null    float64
#  9   geolocation  988 non-null    object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 78.3+ KB

# %%
df['reclat'].replace([np.nan], df['reclat'].mean(), inplace=True)

# %%
df['reclong'].replace([np.nan], df['reclong'].mean(), inplace=True)

# %%
df['year'].unique()
# Out:
# array(['1880-01-01T00:00:00.000', '1951-01-01T00:00:00.000',
#        '1952-01-01T00:00:00.000', '1976-01-01T00:00:00.000',
#        '1902-01-01T00:00:00.000', '1919-01-01T00:00:00.000',
#        '1949-01-01T00:00:00.000', '1814-01-01T00:00:00.000',
#        '1930-01-01T00:00:00.000', '1920-01-01T00:00:00.000',
#        '1974-01-01T00:00:00.000', '1925-01-01T00:00:00.000',
#        '1769-01-01T00:00:00.000', '1838-01-01T00:00:00.000',
#        '1959-01-01T00:00:00.000', '1981-01-01T00:00:00.000',
#        '1957-01-01T00:00:00.000', '2001-01-01T00:00:00.000',
#        '1806-01-01T00:00:00.000', '1766-01-01T00:00:00.000',
#        '2002-01-01T00:00:00.000', '1835-01-01T00:00:00.000',
#        '1873-01-01T00:00:00.000', '1860-01-01T00:00:00.000',
#        '1900-01-01T00:00:00.000', '1883-01-01T00:00:00.000',
#        '1899-01-01T00:00:00.000', '1969-01-01T00:00:00.000',
#        '2008-01-01T00:00:00.000', '1977-01-01T00:00:00.000',
#        '1895-01-01T00:00:00.000', '1898-01-01T00:00:00.000',
#        '1939-01-01T00:00:00.000', nan, '1822-01-01T00:00:00.000',
#        '1869-01-01T00:00:00.000', '1942-01-01T00:00:00.000',
#        '1971-01-01T00:00:00.000', '1984-01-01T00:00:00.000',
#        '1914-01-01T00:00:00.000', '1803-01-01T00:00:00.000',
#        '1954-01-01T00:00:00.000', '1932-01-01T00:00:00.000',
#        '1950-01-01T00:00:00.000', '1805-01-01T00:00:00.000',
#        '2009-01-01T00:00:00.000', '1923-01-01T00:00:00.000',
#        '1886-01-01T00:00:00.000', '1896-01-01T00:00:00.000',
#        '1933-01-01T00:00:00.000', '1945-01-01T00:00:00.000',
#        '1836-01-01T00:00:00.000', '1865-01-01T00:00:00.000',
#        '1842-01-01T00:00:00.000', '1858-01-01T00:00:00.000',
#        '1908-01-01T00:00:00.000', '1855-01-01T00:00:00.000',
#        '1968-01-01T00:00:00.000', '1938-01-01T00:00:00.000',
#        '1934-01-01T00:00:00.000', '1929-01-01T00:00:00.000',
#        '1922-01-01T00:00:00.000', '1907-01-01T00:00:00.000',
#        '1828-01-01T00:00:00.000', '1491-01-01T00:00:00.000',
#        '1636-01-01T00:00:00.000', '1688-01-01T00:00:00.000',
#        '1715-01-01T00:00:00.000', '1773-01-01T00:00:00.000',
#        '1818-01-01T00:00:00.000', '1794-01-01T00:00:00.000',
#        '1647-01-01T00:00:00.000', '1623-01-01T00:00:00.000',
#        '1807-01-01T00:00:00.000'], dtype=object)

# %%
df.select_dtypes(include='object').fillna("NULL", inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         1000 non-null   object
#  1   id           1000 non-null   int64
#  2   nametype     1000 non-null   object
#  3   recclass     1000 non-null   object
#  4   mass         1000 non-null   float64
#  5   fall         1000 non-null   object
#  6   year         999 non-null    object
#  7   reclat       1000 non-null   float64
#  8   reclong      1000 non-null   float64
#  9   geolocation  988 non-null    object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 78.3+ KB

# %%
df.isnull().sum()
# Out:
# name            0
# id              0
# nametype        0
# recclass        0
# mass            0
# fall            0
# year            1
# reclat          0
# reclong         0
# geolocation    12
# dtype: int64

# %%
df = df.fillna(method = 'pad')

# %%
df.isnull().sum()
# Out:
# name           0
# id             0
# nametype       0
# recclass       0
# mass           0
# fall           0
# year           0
# reclat         0
# reclong        0
# geolocation    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         1000 non-null   object
#  1   id           1000 non-null   int64
#  2   nametype     1000 non-null   object
#  3   recclass     1000 non-null   object
#  4   mass         1000 non-null   float64
#  5   fall         1000 non-null   object
#  6   year         1000 non-null   object
#  7   reclat       1000 non-null   float64
#  8   reclong      1000 non-null   float64
#  9   geolocation  1000 non-null   object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 78.3+ KB

# %%
df.head()
# Out:
#        name   id nametype     recclass      mass  fall  \
# 0    Aachen    1    Valid           L5      21.0  Fell
# 1    Aarhus    2    Valid           H6     720.0  Fell
# 2      Abee    6    Valid          EH4  107000.0  Fell
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  Fell
# 4   Achiras  370    Valid           L6     780.0  Fell
#
#                       year    reclat    reclong  \
# 0  1880-01-01T00:00:00.000  50.77500    6.08333
# 1  1951-01-01T00:00:00.000  56.18333   10.23333
# 2  1952-01-01T00:00:00.000  54.21667 -113.00000
# 3  1976-01-01T00:00:00.000  16.88333  -99.90000
# 4  1902-01-01T00:00:00.000 -33.16667  -64.95000
#
#                                          geolocation
# 0  {'type': 'Point', 'coordinates': [6.08333, 50....
# 1  {'type': 'Point', 'coordinates': [10.23333, 56...
# 2  {'type': 'Point', 'coordinates': [-113, 54.216...
# 3  {'type': 'Point', 'coordinates': [-99.9, 16.88...
# 4  {'type': 'Point', 'coordinates': [-64.95, -33....

# %%
df['mass'].unique()
# Out:
# array([2.10000000e+01, 7.20000000e+02, 1.07000000e+05, 1.91400000e+03,
#        7.80000000e+02, 4.23900000e+03, 9.10000000e+02, 3.00000000e+04,
#        1.62000000e+03, 1.44000000e+03, 1.00000000e+03, 2.40000000e+04,
#        5.01901957e+04, 7.79000000e+02, 1.80000000e+03, 3.00000000e+03,
#        5.00000000e+04, 1.60000000e+02, 7.00000000e+02, 6.00000000e+03,
#        2.00000000e+03, 6.25000000e+02, 2.52000000e+02, 3.20000000e+03,
#        9.08000000e+02, 9.25100000e+03, 2.28000000e+05, 3.20000000e+04,
#        2.00000000e+06, 3.95000000e+03, 6.40000000e+03, 2.70000000e+03,
#        6.00000000e+02, 1.79000000e+04, 2.56800000e+02, 1.50000000e+03,
#        6.50000000e+03, 2.50000000e+03, 3.20000000e+02, 1.50000000e+04,
#        8.10000000e+02, 5.07000000e+03, 7.45000000e+03, 4.10000000e+01,
fall  \
# 0    Aachen    1    Valid           L5      21.0  Fell
# 1    Aarhus    2    Valid           H6     720.0  Fell
# 2      Abee    6    Valid          EH4  107000.0  Fell
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  Fell
# 4   Achiras  370    Valid           L6     780.0  Fell
#
#                       year    reclat    reclong  \
# 0  1880-01-01T00:00:00.000  50.77500    6.08333
# 1  1951-01-01T00:00:00.000  56.18333   10.23333
# 2  1952-01-01T00:00:00.000  54.21667 -113.00000
# 3  1976-01-01T00:00:00.000  16.88333  -99.90000
# 4  1902-01-01T00:00:00.000 -33.16667  -64.95000
#
#                                          geolocation
# 0  {'type': 'Point', 'coordinates': [6.08333, 50....
# 1  {'type': 'Point', 'coordinates': [10.23333, 56...
# 2  {'type': 'Point', 'coordinates': [-113, 54.216...
# 3  {'type': 'Point', 'coordinates': [-99.9, 16.88...
# 4  {'type': 'Point', 'coordinates': [-64.95, -33....

# %% [markdown]
# # question
# Get all the Earth meteorites that fell before the year 2000
# ● Get all the earth meteorites co-ordinates who fell before the year 1970
# ● Assuming that the mass of the earth meteorites was in kg, get all those whose mass was more
# than 10000kg

# %%
df[['Year', "month", "day"]] = df['year'].str.split("-", expand = True)

# %%
df.head()
# Out:
#        name   id nametype     recclass      mass  fall  \
# 0    Aachen    1    Valid           L5      21.0  Fell
# 1    Aarhus    2    Valid           H6     720.0  Fell
# 2      Abee    6    Valid          EH4  107000.0  Fell
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  Fell
# 4   Achiras  370    Valid           L6     780.0  Fell
#
#                       year    reclat    reclong  \
# 0  1880-01-01T00:00:00.000  50.77500    6.08333
# 1  1951-01-01T00:00:00.000  56.18333   10.23333
# 2  1952-01-01T00:00:00.000  54.21667 -113.00000
# 3  1976-01-01T00:00:00.000  16.88333  -99.90000
# 4  1902-01-01T00:00:00.000 -33.16667  -64.95000
#
#                                          geolocation  Year month  \
# 0  {'type': 'Point', 'coordinates': [6.08333, 50....  1880    01
# 1  {'type': 'Point', 'coordinates': [10.23333, 56...  1951    01
# 2  {'type': 'Point', 'coordinates': [-113, 54.216...  1952    01
# 3  {'type': 'Point', 'coordinates': [-99.9, 16.88...  1976    01
# 4  {'type': 'Point', 'coordinates': [-64.95, -33....  1902    01
#
#                day
# 0  01T00:00:00.000
# 1  01T00:00:00.000
# 2  01T00:00:00.000
# 3  01T00:00:00.000
# 4  01T00:00:00.000

# %%
df['Year'].isnull().sum()
# Out:
# 0

# %%
df['Year'].unique()
# Out:
# array(['1880', '1951', '1952', '1976', '1902', '1919', '1949', '1814',
#        '1930', '1920', '1974', '1925', '1769', '1838', '1959', '1981',
#        '1957', '2001', '1806', '1766', '2002', '1835', '1873', '1860',
#        '1900', '1883', '1899', '1969', '2008', '1977', '1895', '1898',
#        '1939', '1822', '1869', '1942', '1971', '1984', '1914', '1803',
#        '1954', '1932', '1950', '1805', '2009', '1923', '1886', '1896',
#        '1933', '1945', '1836', '1865', '1842', '1858', '1908', '1855',
#        '1968', '1938', '1934', '1929', '1922', '1907', '1993', '1871',
#        '1892', '1913', '1790', '1704', '1904', '1910', '1965', '2006',
#        '1994', '2012', '1989', '1916', '1893', '1961', '1937', '1798',
#        '2004', '1943', '1924', '1811', '1859', '1921', '1877', '1940',
#        '1905', '1827', '1887', '1999', '1843', '1796', '1941', '1906',
#        '1909', '1833', '1804', '1962', '1808', '1894', '1852', '1812',
#        '1823', '2003', '2011', '1847', '1956', '1960', '1964', '2007',
#        '1990', '1946', '1863', '1861', '1870', '1991', '1866', '1973',
#        '1846', '1874', '1791', '1848', '1583', '1810', '1988', '1840',
#        '1998', '1885', '1834', '1815', '1841', '2013', '1901', '1966',
#        '1978', '1979', '1917', '1890', '1844', '1936', '1878', '1868',
#        '1829', '1897', '1911', '1967', '1884', '1903', '1864', '1995',
#        '1970', '1853', '1872', '1947', '1785', '1400', '1492', '1889',
#        '1837', '1879', '1875', '1996', '1944', '1882', '1654', '1826',
#        '2000', '1918', '1881', '1983', '1980', '1891', '1972', '1982',
#        '1851', '1817', '1628', '1857', '1912', '1825', '1963', '1751',
#        '2010', '1975', '1928', '1926', '1621', '1819', '1997', '1876',
#        '1821', '1955', '1850', '1787', '1867', '1809', '1986', '1931',
#        '1985', '1987', '1830', '1845', '1813', '1854', '1839', '1820',
#        '1935', '1768', '1753', '1927', '1948', '1801', '1992', '1953',
#        '1915', '1862', '1632', '1849', '1637', '1795', '0921', '1750',
#        '0861', '1662', '1741', '1958', '1520', '1671', '1856', '1775',
#        '1779', '1723', '1740', '1824', '1828', '1491', '1636', '1688',
#        '1715', '1773', '1818', '1794', '1647', '1623', '1807'],
#       dtype=object)

# %%
df=df.drop(['month','day'],axis=1)

# %%
   df.info()#df['Year'].fillna(method = 'pad')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         1000 non-null   object
#  1   id           1000 non-null   int64
#  2   nametype     1000 non-null   object
#  3   recclass     1000 non-null   object
#  4   mass         1000 non-null   float64
#  5   fall         1000 non-null   object
#  6   year         1000 non-null   object
#  7   reclat       1000 non-null   float64
#  8   reclong      1000 non-null   float64
#  9   geolocation  1000 non-null   object
#  10  Year         1000 non-null   object
#  11  month        1000 non-null   object
#  12  day          1000 non-null   object
# dtypes: float64(3), int64(1), object(9)
# memory usage: 101.7+ KB

# %%
df.head()
# Out:
#        name   id nametype     recclass      mass  fall  \
# 0    Aachen    1    Valid           L5      21.0  Fell
# 1    Aarhus    2    Valid           H6     720.0  Fell
# 2      Abee    6    Valid          EH4  107000.0  Fell
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  Fell
# 4   Achiras  370    Valid           L6     780.0  Fell
#
#                       year    reclat    reclong  \
# 0  1880-01-01T00:00:00.000  50.77500    6.08333
# 1  1951-01-01T00:00:00.000  56.18333   10.23333
# 2  1952-01-01T00:00:00.000  54.21667 -113.00000
# 3  1976-01-01T00:00:00.000  16.88333  -99.90000
# 4  1902-01-01T00:00:00.000 -33.16667  -64.95000
#
#                                          geolocation  Year
# 0  {'type': 'Point', 'coordinates': [6.08333, 50....  1880
# 1  {'type': 'Point', 'coordinates': [10.23333, 56...  1951
# 2  {'type': 'Point', 'coordinates': [-113, 54.216...  1952
# 3  {'type': 'Point', 'coordinates': [-99.9, 16.88...  1976
# 4  {'type': 'Point', 'coordinates': [-64.95, -33....  1902

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         1000 non-null   object
#  1   id           1000 non-null   int64
#  2   nametype     1000 non-null   object
#  3   recclass     1000 non-null   object
#  4   mass         1000 non-null   float64
#  5   fall         1000 non-null   object
#  6   year         1000 non-null   object
#  7   reclat       1000 non-null   float64
#  8   reclong      1000 non-null   float64
#  9   geolocation  1000 non-null   object
#  10  Year         1000 non-null   object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 86.1+ KB

# %%
df['Year']=df['Year'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         1000 non-null   object
#  1   id           1000 non-null   int64
#  2   nametype     1000 non-null   object
#  3   recclass     1000 non-null   object
#  4   mass         1000 non-null   float64
#  5   fall         1000 non-null   object
#  6   year         1000 non-null   object
#  7   reclat       1000 non-null   float64
#  8   reclong      1000 non-null   float64
#  9   geolocation  1000 non-null   object
#  10  Year         1000 non-null   int32
# dtypes: float64(3), int32(1), int64(1), object(6)
# memory usage: 82.2+ KB

# %% [markdown]
# # question
# Get all the Earth meteorites that fell before the year 2000
# ● Get all the earth meteorites co-ordinates who fell before the year 1970
# ● Assuming that the mass of the earth meteorites was in kg, get all those whose mass was more
# than 10000kg

# %%
filtered_df = df[df['Year']<2000]

# %%
filtered_df['name']
# Out:
# 0         Aachen
# 1         Aarhus
# 2           Abee
# 3       Acapulco
# 4        Achiras
#          ...
# 994     Timochin
# 995     Tirupati
# 997        Tjabe
# 998     Tjerebon
# 999    Tomakovka
# Name: name, Length: 930, dtype: object

# %% [markdown]
# # Get all the earth meteorites co-ordinates who fell before the year 1970

# %%
filtered_df = df[df['Year']<1970]

# %%
filtered_df['geolocation']
# Out:
# 0      {'type': 'Point', 'coordinates': [6.08333, 50....
# 1      {'type': 'Point', 'coordinates': [10.23333, 56...
# 2      {'type': 'Point', 'coordinates': [-113, 54.216...
# 4      {'type': 'Point', 'coordinates': [-64.95, -33....
# 5         {'type': 'Point', 'coordinates': [71.8, 32.1]}
#                              ...
# 994       {'type': 'Point', 'coordinates': [35.2, 54.5]}
# 995    {'type': 'Point', 'coordinates': [79.41667, 13...
# 997    {'type': 'Point', 'coordinates': [111.53333, -...
# 998    {'type': 'Point', 'coordinates': [106.58333, -...
# 999    {'type': 'Point', 'coordinates': [34.76667, 47...
# Name: geolocation, Length: 781, dtype: object

# %%
df.head()
# Out:
#        name   id nametype     recclass      mass  fall  \
# 0    Aachen    1    Valid           L5      21.0  Fell
# 1    Aarhus    2    Valid           H6     720.0  Fell
# 2      Abee    6    Valid          EH4  107000.0  Fell
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  Fell
# 4   Achiras  370    Valid           L6     780.0  Fell
#
#                       year    reclat    reclong  \
# 0  1880-01-01T00:00:00.000  50.77500    6.08333
# 1  1951-01-01T00:00:00.000  56.18333   10.23333
# 2  1952-01-01T00:00:00.000  54.21667 -113.00000
# 3  1976-01-01T00:00:00.000  16.88333  -99.90000
# 4  1902-01-01T00:00:00.000 -33.16667  -64.95000
#
#                                          geolocation  Year
# 0  {'type': 'Point', 'coordinates': [6.08333, 50....  1880
# 1  {'type': 'Point', 'coordinates': [10.23333, 56...  1951
# 2  {'type': 'Point', 'coordinates': [-113, 54.216...  1952
# 3  {'type': 'Point', 'coordinates': [-99.9, 16.88...  1976
# 4  {'type': 'Point', 'coordinates': [-64.95, -33....  1902

# %% [markdown]
# # Assuming that the mass of the earth meteorites was in kg, get all those whose mass was more than 10000kg

# %%
filtered_df = df[df['mass']>10000]

# %%
filtered_df['mass'].unique()
# Out:
# array([1.07000000e+05, 3.00000000e+04, 2.40000000e+04, 5.01901957e+04,
#        5.00000000e+04, 2.28000000e+05, 3.20000000e+04, 2.00000000e+06,
#        1.79000000e+04, 1.50000000e+04, 1.80000000e+04, 1.03220000e+04,
#        1.67000000e+04, 1.15000000e+04, 4.40000000e+04, 2.95600000e+04,
